# %% [markdown]
# <div align="center">
#
# <h1 style="font-size: 22px;"><b>LAPORAN PRAKTIKUM</b></h1>
#
# <h2 style="font-size: 18px;"><b>ALGORITMA DAN PEMROGRAMAN</b></h2>
#
# <h2 style="font-size: 18px;"><b>“Pengenalan Tipe Data dan Variabel Python”</b></h2>
#
# <h4 style="font-size: 16px;"><b>Disusun Oleh :</b></h4>
#
# <h4 style="font-size: 16px;"><b>Rizki Ramadhani Al Michtari</b></h4>
#
# <h4 style="font-size: 16px;"><b>2611532001</b><h4>
#
# <h4 style="font-size: 16px;"><b>Dosen Pengampu:</b></h4>
#
# <h4 style="font-size: 16px;"><b>Dr. Ir. Wahyudi, S.T., M.T.</b></h4>
#
# <h4 style="font-size: 16px;"><b>Asisten Praktikum:</b></h4>
#
# <h4 style="font-size: 16px;"><b>Rifki Yuliandra</b></h4>
#
# </div>

# %% [markdown]
# <div align="center">
#
# <img src="images/logo_unand.png" width="200">
#
# </div>

# %% [markdown]
# <div align="center">
#
# <h3 style="font-size: 18px;"><b>FAKULTAS TEKNOLOGI INFORMASI</b></h3>
#
# <h3 style="font-size: 18px;"><b>DEPARTEMEN INFORMATIKA</b></h3>
#
# <h3 style="font-size: 18px;"><b>UNIVERSITAS ANDALAS</b></h3>
#
# <h3 style="font-size: 18px;"><b>2026</b></h3>
#
#
# </div>

# %% [markdown]
# <div align="center">
#
# <h1><b>KATA PENGANTAR</b></h1>
#
# </div>
#
# Puji beserta syukur saya panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga saya dapat menyelesaikan laporan praktikum mengenai pengenalan tipe data dan variabel Python yang telah dilaksanakan sebagai pertemuan ke-2 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan jenis - jenis tipe data yang ada pada bahasa pemrograman Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah saya dapat memahami secara langsung konsep mengenai macam - macam tipe data Python dan bisa mengindentifikasi nilai dari suatu variabel serta bisa mengelompokkan nilai variabel berdasarkan tipe datanya pada bahasa pemrograman Python.
#
# Saya menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
#
# Hormat saya,
#
# (Rizki Ramadhani Al Michtari)

# %% [markdown]
# <div align="center>## KATA PENGANTAR<div>
#
# Puji syukur penulis panjatkan kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum mengenai pengenalan Python, VS Code, dan pengkoneksian folder lokal ke reporitory GitHub yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan bagaimana cara memasang VS Code di komputer, ekstensi Python di VS Code, bikin kode Python, serta bagaimana cara menghubungkan VS Code dengan GitHub, dan _commit_ kode di VS Code ke GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep pembuatan kode program Python di VS Code serta melakukan _commit_ kode ke GitHub pada _real project_.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, September 2026
#
# Penulis,
#
# (Rizki Ramadhani Al Michtari)

# %% [markdown]
# ---
# <div align="center">
#
# <h1><b>BAB I</b><h1>
#
# <h1><b>PENDAHULUAN</b></h1>
#
# </div>
#
# <h2><b>1.1 Latar Belakang</b></h2>
#
# Perkembangan teknologi informasi saat ini mendorong kebutuhan akan pengolahan data dan otomasi sistem yang cepat serta efisien. Dalam dunia pemrograman, bahasa Python menjadi salah satu bahasa yang sangat populer dan luas digunakan karena sintaksisnya yang sederhana, mudah dipahami, serta memiliki fleksibilitas tinggi untuk berbagai bidang seperti pengembangan perangkat lunak, analisis data, hingga kecerdasan buatan. Untuk membangun sebuah program yang fungsional di dalam Python, pemahaman mengenai konsep-konsep dasar pemrograman menjadi fondasi yang sangat krusial.
#
# ​Salah satu konsep paling mendasar dalam pemrograman adalah variabel. Dalam proses eksekusi kode, program membutuhkan mekanisme untuk menyimpan nilai atau data sementara di dalam memori komputer. Variabel bertindak sebagai penanda atau wadah berlabel yang memungkinkan pemrogram untuk menyimpan, mengakses, dan memanipulasi data tersebut di berbagai bagian dari alur program. Tanpa adanya variabel, pengolahan data secara dinamis akan sangat sulit dilakukan.
#
# ​Selain variabel, setiap data yang disimpan dan diproses memiliki karakteristik tertentu yang didefinisikan melalui tipe data. Tipe data dasar seperti integer (`int`), float (`float`), string (`str`), dan boolean (`bool`) menentukan jenis nilai yang dikandung serta operasi apa saja yang dapat dilakukan terhadap data tersebut. Berbeda dengan beberapa bahasa pemrograman lain yang mewajibkan deklarasi tipe data secara eksplisit, Python menggunakan sistem dynamic typing di mana tipe data ditentukan secara otomatis saat nilai diberikan. Meskipun memberikan kemudahan dan kecepatan dalam penulisan kode, karakteristik ini tetap menuntut pemrogram untuk memahami sifat tiap tipe data agar tidak terjadi kesalahan logika maupun operasional.
#
# ​Pemahaman mengenai variabel dan tipe data merupakan langkah awal yang wajib dikuasai sebelum mempelajari konsep pemrograman yang lebih kompleks, seperti struktur kendali, fungsi, maupun struktur data tingkat lanjut. Kesalahan dalam mengenali atau memanipulasi tipe data sering kali menjadi penyebab utama terjadinya galat (error) saat program dijalankan. Oleh karena itu, praktikum pengenalan variabel dan tipe data Python ini dilaksanakan agar praktikan dapat memahami secara langsung (hands-on) cara mendeklarasikan variabel, mengenali berbagai tipe data dasar, serta mengoperasikannya secara tepat dalam sintaksis bahasa Python.
#
# <h2><b>1.2 Tujuan</b></h2>
#
# 1. Memahami Konsep Dasar Variabel.
# 2. Mengenali Jenis Tipe Data Variabel.
# 3. Mengimplementasikan Deklarasi dan Konversi Tipe Data.
# 4. Menganalisis dan Mengatasi Galat (Error).
#
# <h2><b>1.3 Manfaat</b></h2>
#
# 1. Penguasaan Fondasi Pemrograman
# 2. Peningkatan Keterampilan Praktis (Hands-On)
# 3. Pencegahan Kesalahan Logika Kode

# %% [markdown]
# ---
# <div align="center">
#
# <h1><b>BAB II</b><h1>
#
# <h1><b>PEMBAHASAN</b></h1>
#
# </div>
#
# <h2><b>2.1 Landasan Teori</b></h2>
#
# **1. Pengenalan Bahasa Pemrograman Python**
#
# ​Python merupakan bahasa pemrograman tingkat tinggi (_high-level language_) yang bersifat _interpreted_, _object-oriented_, dan _dynamically typed_. Diciptakan oleh Guido van Rossum pada tahun 1991, Python dirancang dengan penekanan pada keterbacaan kode (_code readability_) melalui penggunaan indentasi yang bersih. Sintaksisnya yang intuitif membuat Python banyak digunakan dalam berbagai bidang, mulai dari pengembangan perangkat lunak, otomatisasi sistem, hingga analisis data dan kecerdasan buatan.
#
# ​**2. Konsep Variabel dalam Python**
#
# ​Variabel merupakan nama atau label berpenunjuk (_identifier_) yang terikat pada suatu lokasi di memori komputer untuk menyimpan nilai tertentu. Dalam Python, variabel tidak perlu dideklarasikan secara eksplisit beserta tipe datanya sebelum digunakan; variabel dibuat secara otomatis saat suatu nilai dialokasikan padanya menggunakan operator penugasan (`=`). Penulisan nama variabel di Python harus mengikuti aturan tertentu, seperti bersifat case-sensitive, tidak boleh diawali oleh angka, dan tidak boleh menggunakan kata kunci (_keywords_) bawaan sistem.
#
# **​3. Tipe Data Dasar (Primitive Data Types)**
#
# ​Tipe data mengklasifikasikan jenis nilai yang dimiliki oleh suatu variabel sehingga sistem mengetahui cara mengolah dan menyimpan data tersebut di memori. Python memiliki beberapa tipe data dasar yang sering digunakan:
#
# > * ​Integer (`int`): Tipe data berupa bilangan bulat, baik positif maupun negatif, tanpa komponen desimal (contoh: `-5`, `0`, `100`).
#
# > * ​Floating-Point (`float`): Tipe data berupa angka yang memiliki titik desimal atau pecahan (contoh: `3.14`, `-0.01`).
#
# > * ​String (`str`): Tipe data berupa urutan karakter/teks yang diapit oleh tanda petik tunggal (`'...'`) atau ganda (`"..."`) (contoh: `"Praktikum Python"`).
#
# > * ​Boolean (`bool`): Tipe data logika yang hanya memiliki dua nilai kebenaran, yaitu `True` (benar) dan `False` (salah).
#
# **​4. Dynamic Typing dan Type Casting**
#
# ​Python menganut sistem _dynamic typing_, yang berarti tipe data dari suatu variabel ditentukan secara otomatis pada saat program berjalan (_runtime_) berdasarkan nilai yang dimasukkan, bukan saat variabel dideklarasikan. Selain itu, Python mendukung konversi tipe data atau _type casting_, yaitu proses mengubah nilai dari satu tipe data ke tipe data lainnya secara eksplisit (seperti menggunakan fungsi `int()`, `float()`, atau `str()`) maupun implisit oleh interpreter. Pemahaman terhadap type casting sangat penting untuk menghindari kesalahan tipe data (_type error_) saat melakukan operasi aritmetika atau manipulasi string.

# %% [markdown]
# <h2><b>2.2 Kode Program</b></h2>
#
# <h3><b>2.2.1 Program "Numerik_2611532001.py"</b></h3>

# %%
# Create a variable with integer value
a_2001 = 100
print("The type of variable having value", a_2001,"is", type(a_2001))

# Create a variable with integer value
b_2001 = 10.2345
print("The type of variable having value", b_2001,"is", type(b_2001))

# Create a variable with integer value
c_2001 = 100+3j
print("The type of variable having value", c_2001,"is", type(c_2001))
# Out:
# The type of variable having value 100 is <class 'int'>
# The type of variable having value 10.2345 is <class 'float'>
# The type of variable having value (100+3j) is <class 'complex'>

# %% [markdown]
# **Penjelasan :**
#
# **1. Membuat Komentar 1 Baris:** Pada sintaks
# `# Program Pertama`
# terdapat simbol `#` yang berfungsi untuk memberikan komentar untuk 1 baris kode. Jika ingin menambahkan komentar lagi dengan simbol yang sama, maka di baris berikutnya harus diawali juga dengan simbol `#`.
#
# **2. Membuat Komentar Lebih dari 1 Baris:** Pada sintaks
# `"""`
# `Komentar`
# `dua baris atau lebih`
# `pertemuan 1 praktikum alpro`
# `"""`
# terdapat simbol 3 buah petik ganda (`"""`) yang berfungsi untuk memberikan komentar di kode program yang lebih dari 1 baris. Cara ini lebih efisien daripada menggunakan simbol `#` untuk membuat komentar dengan lebih dari 1 baris.
#
# Note : Program Python tidak akan mengeluarkan output apapun dari komentar yang ada di kodenya. Komentar merupakan suatu sintak kode yang digunakan untuk memberikan penjelasan atau catatan yang tidak akan dieksekusi oleh program.
#
# **3. Mengeluarkan _Output_ pada Program Python:** Pada sintaks
# `print("Hello World")`
# terdapat fungsi `print` yang berfungsi untuk mengeluarkan _output_ `Hello World`. Dari sintaks `print("Hello World")`. Selain mengeluarkan output _string_, fungsi `print` juga bisa digunakan untuk mengeluarkan _output_ nilai dari suatu _variabel_ di dalam program. Contoh, jika terdapat sintaks `x=5  print(x)`, maka program akan mengeluarkan nilai dari `x` yaitu `5`.
#
# **4. Menggabungkan String:** Pada sintaks
# `print("program ini" + " dibuat oleh a/n "`
# `+ "Rizki Ramadhani Al Michtari dan 2611532001.")`
# terdapat simbol `+` yang berfungsi untuk mengeluarkan _output_ yang menggabungkan 2 atau lebih _string_. _String_ `program ini` dan _string_ ` dibuat oleh a/n` digabung menjadi 1 kalimat pada _output_ program kode Python, sehingga menjadi `program ini dibuat oleh a/n`, begitu pula dengan _string_ `Rizki Ramadhani Al Michtari dan 2611532001.`

# %% [markdown]
# <h3><b>2.2.2 Program "String_2611532001.py"</b></h3>

# %%
# Nama variabel ditambah 4 digit nim terakhir contoh: nama_1234
# Ganti programnya dan data masing masing

nama_2001 = "Rizki Ramadhani Al Michtari"
jenis_kelamin_2001 = 'L'
alamat_2001 = """
    Asrama Hijau Universitas Andalas
    Kecamatan Pauh
    Kota Padang
"""
agama_2001 = "Islam"

print("Nama saya adalah: ", nama_2001)
print("Jenis kelamin saya adalah: ", jenis_kelamin_2001)
print("Alamat saya adalah: ", alamat_2001)
print("Agama saya adalah: ", agama_2001)
# Out:
# Nama saya adalah:  Rizki Ramadhani Al Michtari
# Jenis kelamin saya adalah:  L
# Alamat saya adalah:
#     Asrama Hijau Universitas Andalas
#     Kecamatan Pauh
#     Kota Padang
#
# Agama saya adalah:  Islam

# %% [markdown]
# **Penjelasan :**
#
# **1. Membuat Komentar 1 Baris:** Pada sintaks
# `# Program Pertama`
# terdapat simbol `#` yang berfungsi untuk memberikan komentar untuk 1 baris kode. Jika ingin menambahkan komentar lagi dengan simbol yang sama, maka di baris berikutnya harus diawali juga dengan simbol `#`.
#
# **2. Membuat Komentar Lebih dari 1 Baris:** Pada sintaks
# `"""`
# `Komentar`
# `dua baris atau lebih`
# `pertemuan 1 praktikum alpro`
# `"""`
# terdapat simbol 3 buah petik ganda (`"""`) yang berfungsi untuk memberikan komentar di kode program yang lebih dari 1 baris. Cara ini lebih efisien daripada menggunakan simbol `#` untuk membuat komentar dengan lebih dari 1 baris.
#
# Note : Program Python tidak akan mengeluarkan output apapun dari komentar yang ada di kodenya. Komentar merupakan suatu sintak kode yang digunakan untuk memberikan penjelasan atau catatan yang tidak akan dieksekusi oleh program.
#
# **3. Mengeluarkan _Output_ pada Program Python:** Pada sintaks
# `print("Hello World")`
# terdapat fungsi `print` yang berfungsi untuk mengeluarkan _output_ `Hello World`. Dari sintaks `print("Hello World")`. Selain mengeluarkan output _string_, fungsi `print` juga bisa digunakan untuk mengeluarkan _output_ nilai dari suatu _variabel_ di dalam program. Contoh, jika terdapat sintaks `x=5  print(x)`, maka program akan mengeluarkan nilai dari `x` yaitu `5`.
#
# **4. Menggabungkan String:** Pada sintaks
# `print("program ini" + " dibuat oleh a/n "`
# `+ "Rizki Ramadhani Al Michtari dan 2611532001.")`
# terdapat simbol `+` yang berfungsi untuk mengeluarkan _output_ yang menggabungkan 2 atau lebih _string_. _String_ `program ini` dan _string_ ` dibuat oleh a/n` digabung menjadi 1 kalimat pada _output_ program kode Python, sehingga menjadi `program ini dibuat oleh a/n`, begitu pula dengan _string_ `Rizki Ramadhani Al Michtari dan 2611532001.`

# %% [markdown]
# <h3><b>2.2.3 Program "Konstanta_2611532001.py"</b></h3>

# %%
# Program ini menggunakan konstanta untuk menghitung luas lingkaran
# Nama variabel ditambah 4 digit nim terakhir contoh: jari_1234

from typing import Final
PI: Final = 3.14

print("pi: %f" % (PI))

jari_2001 = float(input('Masukkan nilai jari-jari: '))
luas_2001 = PI * jari_2001 * jari_2001

print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_2001, luas_2001))
# Out:
# pi: 3.140000
# Masukkan nilai jari-jari: 8
# Luas lingkaran dengan jari-jari 8.00 adalah 200.96

# %% [markdown]
# <h3><b>2.2.4 Program "Input_2611532001.py"</b></h3>

# %%
# Buat program untuk menghitung luas persegi panjang
# Nama variabel ditambah 4 digit nim terakhir contoh: panjang 1234
# Program ini menggunakan fungsi input() untuk meminta pengguna
# Memasukkan nilai panjang dan lebar persegi panjang.
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

panjang_2001 = input('Masukkan nilai panjang: ')
lebar_2001 = input('Masukkan nilai lebar: ')

luas_2001 = int(panjang_2001) * int(lebar_2001)
print("Luas = ", luas_2001)
# Out:
# Masukkan nilai panjang: 8
# Masukkan nilai lebar: 5
# Luas =  40

# %% [markdown]
# <h3><b>2.2.5 Program "Boolean_2611532001.py"</b></h3>

# %%
# Nama variabel ditambah 4 digit nim terakhir contoh: nama_1234
# Deklarasi variabel dengan tipe data Boolean

is_lulus_2001 = True
is_cumlaude_2001 = True

# Menggunakan boolean
nilai_2001 = 85
batas_lulus_2001 = 75

# Menentukan nilai boolean dari kondisi
status_kelulusan_2001 = nilai_2001 >= batas_lulus_2001 # Hasilnya akan True

print("=== Check Kelulusan ===")
print("Nilai: ", nilai_2001)
print("Apakah lulus?: ", status_kelulusan_2001)
if is_lulus_2001 and is_cumlaude_2001:
    print("Selamat, Anda lulus dengan predikat Cum Laude!")
# Out:
# === Check Kelulusan ===
# Nilai:  85
# Apakah lulus?:  True
# Selamat, Anda lulus dengan predikat Cum Laude!

# %% [markdown]
# ---
# <div align="center">
#
# <h1><b>BAB III</b><h1>
#
# <h1><b>KESIMPULAN</b></h1>
#
# </div>
#
# Berdasarkan rangkaian kegiatan praktikum Algoritma dan Pemrograman yang telah dilaksanakan, dapat ditarik beberapa kesimpulan sebagai berikut:
#
# **1. Bahasa Pemrograman Python:** Python merupakan bahasa pemrograman yang dinamis dan mudah dipahami, sangat cocok digunakan sebagai dasar pembelajaran logika pemrograman dan pengembangan perangkat lunak karena memiliki sintaks yang bersih dan terstruktur.
#
# ​**2. Lingkungan Pengembangan (Development Environment):** Penggunaan lingkungan kerja seperti code editor (VS Code) atau platform komputasi awan (Google Colab) sangat membantu dalam proses penulisan, pengelolaan, serta pengujian kode program Python secara efisien.
#
# **​3. Manajemen Kode dan GitHub:** Penggunaan sistem kontrol versi (version control system) seperti Git dan platform GitHub merupakan keterampilan esensial bagi pengembang. Proses pengelolaan repositori dari terminal—mulai dari git init, add, commit, hingga push menggunakan Personal Access Token (PAT)—memungkinkan pengkodean dikelola secara profesional, aman, dan terstruktur, terutama dengan menerapkan praktik keamanan yang tepat saat bekerja di komputer lab.

# %% [markdown]
# ---
# <div align="center">
#
# <h1><b>DAFTAR PUSTAKA</b></h1>
#
# </div>
#
# [1] ​Lubanovic, B. (2019). Introducing Python: Modern Computing in Simple Packages (2nd ed.). O'Reilly Media. Link: https://www.oreilly.com/library/view/introducing-python-2nd/9781492051374/
#
# [2] ​Matthes, E. (2019). Python Crash Course: A Hands-On, Project-Based Introduction to Programming (2nd ed.). No Starch Press. Link: https://nostarch.com/pythoncrashcourse2e
#
# [3] ​Severance, C. R. (2016). Python for Everybody: Exploring Data in Python 3. CreateSpace Independent Publishing Platform. Link: https://www.py4e.com/book
#
# [4] ​Swaroop, C. H. (2013). A Byte of Python. Link: https://python.swaroopch.com/
